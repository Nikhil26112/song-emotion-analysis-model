# %%
#Script to obtain data 
from helpers import *
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

#Libraries to create the multiclass model
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from keras.utils import np_utils
#Import tensorflow and disable the v2 behavior and eager mode
import tensorflow as tf
tf.compat.v1.disable_eager_execution()
tf.compat.v1.disable_v2_behavior()

#Library to validate the model
from sklearn.model_selection import cross_val_score, KFold, train_test_split
from sklearn.preprocessing import LabelEncoder,MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
df = pd.read_csv("data/data_moods.csv")

# %%
col_features = df.columns[6:-3]
X= MinMaxScaler().fit_transform(df[col_features])
X2 = np.array(df[col_features])
Y = df['mood']

# %%
#Encodethe categories
encoder = LabelEncoder()
encoder.fit(Y)
encoded_y = encoder.transform(Y)


#Convert to  dummy (Not necessary in my case)
dummy_y = np_utils.to_categorical(encoded_y)

X_train,X_test,Y_train,Y_test = train_test_split(X,encoded_y,test_size=0.2,random_state=15)

target = pd.DataFrame({'mood':df['mood'].tolist(),'encode':encoded_y}).drop_duplicates().sort_values(['encode'],ascending=True)
target
# Out:
#         mood  encode
# 5       Calm       0
# 4  Energetic       1
# 0      Happy       2
# 1        Sad       3

# %%
def base_model():
    #Create the model
    model = Sequential()
    #Add 1 layer with 8 nodes,input of 4 dim with relu function
    model.add(Dense(8,input_dim=10,activation='relu'))
    #Add 1 layer with output 3 and softmax function
    model.add(Dense(4,activation='softmax'))
    #Compile the model using sigmoid loss function and adam optim
    model.compile(loss='categorical_crossentropy',optimizer='adam',
                 metrics=['accuracy'])
    return model

# %%
#Configure the model
estimator = KerasClassifier(build_fn=base_model,epochs=300,batch_size=200,verbose=0)
# Out:
# /tmp/ipykernel_19696/2455418095.py:2: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   estimator = KerasClassifier(build_fn=base_model,epochs=300,batch_size=200,verbose=0)

# %%
#Evaluate the model using KFold cross validation
kfold = KFold(n_splits=10,shuffle=True)
results = cross_val_score(estimator,X,encoded_y,cv=kfold)
print("Baseline: %.2f%% (%.2f%%)" % (results.mean()*100,results.std()*100))
# Out:
# 2023-04-28 00:44:22.734940: W tensorflow/c/c_api.cc:300] Operation '{name:'dense_291/bias/Assign' id:43984 op device:{requested: '', assigned: ''} def:{{{node dense_291/bias/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_291/bias, dense_291/bias/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# /home/nikhil/.local/lib/python3.10/site-packages/keras/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2023-04-28 00:44:29.772900: W tensorflow/c/c_api.cc:300] Operation '{name:'loss_145/mul' id:44066 op device:{requested: '', assigned: ''} def:{{{node loss_145/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_145/mul/x, loss_145/dense_291_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-04-28 00:44:32.413925: W tensorflow/c/c_api.cc:300] Operation '{name:'training_292/Adam/beta_2/Assign' id:44457 op device:{requested: '', assigned: ''} def:{{{node training_292/Adam/beta_2/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training_292/Adam/beta_2, training_292/Adam/beta_2/Initializer/initial_value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-04-28 00:44:39.304813: W tensorflow/c/c_api.cc:300] Operation '{name:'loss_146/mul' id:44388 op device:{requested: '', assigned: ''} def:{{{node loss_146/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_146/mul/x, loss_146/dense_293_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-04-28 00:44:42.029754: W tensorflow/c/c_api.cc:300] Operation '{name:'dense_294/bias/Assign' id:44588 op device:{requested: '', assigned: ''} def:{{{node dense_294/bias/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_294/bias, dense_294/bias/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-04-28 00:44:48.838745: W tensorflow/c/c_api.cc:300] Operation '{name:'loss_147/mul' id:44691 op device:{requested: '', assigned: ''} def:{{{node loss_147/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_147/mul/x, loss_147/dense_295_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-04-28 00:44:51.538300: W tensorflow/c/c_api.cc:300] Operation '{name:'training_296/Adam/dense_297/bias/m/Assign' id:45093 op device:{requested: '', assigned: ''} def:{{{node training_296/Adam/dense_297/bias/m/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training_296/Adam/dense_297/bias/m, training_296/Adam/dense_297/bias/m/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-04-28 00:44:58.301935: W tensorflow/c/c_api.cc:300] Operation '{name:'loss_148/mul' id:44994 op device:{requested: '', assigned: ''} def:{{{node loss_148/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_148/mul/x, loss_148/dense_297_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-04-28 00:45:00.884492: W tensorflow/c/c_api.cc:300] Operation '{name:'training_298/Adam/dense_298/bias/m/Assign' id:45386 op device:{requested: '', assigned: ''} def:{{{node training_298/Adam/dense_298/bias/m/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training_298/Adam/dense_298/bias/m, training_298/Adam/dense_298/bias/m/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-04-28 00:45:07.647840: W tensorflow/c/c_api.cc:300] Operation '{name:'loss_149/mul' id:45297 op device:{requested: '', assigned: ''} def:{{{node loss_149/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_149/mul/x, loss_149/dense_299_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-04-28 00:45:10.821552: W tensorflow/c/c_api.cc:300] Operation '{name:'training_300/Adam/dense_300/bias/m/Assign' id:45689 op device:{requested: '', assigned: ''} def:{{{node training_300/Adam/dense_300/bias/m/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training_300/Adam/dense_300/bias/m, training_300/Adam/dense_300/bias/m/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-04-28 00:45:17.945088: W tensorflow/c/c_api.cc:300] Operation '{name:'loss_150/mul' id:45600 op device:{requested: '', assigned: ''} def:{{{node loss_150/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_150/mul/x, loss_150/dense_301_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-04-28 00:45:20.679343: W tensorflow/c/c_api.cc:300] Operation '{name:'dense_303/kernel/Assign' id:45816 op device:{requested: '', assigned: ''} def:{{{node dense_303/kernel/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_303/kernel, dense_303/kernel/Initializer/random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-04-28 00:45:27.685001: W tensorflow/c/c_api.cc:300] Operation '{name:'loss_151/mul' id:45903 op device:{requested: '', assigned: ''} def:{{{node loss_151/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_151/mul/x, loss_151/dense_303_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-04-28 00:45:30.574855: W tensorflow/c/c_api.cc:300] Operation '{name:'training_304/Adam/learning_rate/Assign' id:46285 op device:{requested: '', assigned: ''} def:{{{node training_304/Adam/learning_rate/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training_304/Adam/learning_rate, training_304/Adam/learning_rate/Initializer/initial_value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-04-28 00:45:37.825145: W tensorflow/c/c_api.cc:300] Operation '{name:'loss_152/mul' id:46206 op device:{requested: '', assigned: ''} def:{{{node loss_152/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_152/mul/x, loss_152/dense_305_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-04-28 00:45:40.640183: W tensorflow/c/c_api.cc:300] Operation '{name:'training_306/Adam/dense_307/kernel/m/Assign' id:46603 op device:{requested: '', assigned: ''} def:{{{node training_306/Adam/dense_307/kernel/m/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training_306/Adam/dense_307/kernel/m, training_306/Adam/dense_307/kernel/m/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-04-28 00:45:48.258655: W tensorflow/c/c_api.cc:300] Operation '{name:'loss_153/mul' id:46509 op device:{requested: '', assigned: ''} def:{{{node loss_153/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_153/mul/x, loss_153/dense_307_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-04-28 00:45:51.088445: W tensorflow/c/c_api.cc:300] Operation '{name:'training_308/Adam/dense_308/bias/m/Assign' id:46901 op device:{requested: '', assigned: ''} def:{{{node training_308/Adam/dense_308/bias/m/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training_308/Adam/dense_308/bias/m, training_308/Adam/dense_308/bias/m/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-04-28 00:45:58.291648: W tensorflow/c/c_api.cc:300] Operation '{name:'loss_154/mul' id:46812 op device:{requested: '', assigned: ''} def:{{{node loss_154/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_154/mul/x, loss_154/dense_309_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Baseline: 78.87% (4.49%)

# %%
estimator.fit(X_train,Y_train)
y_preds = estimator.predict(X_test)
# Out:
# 2023-04-28 00:46:01.199406: W tensorflow/c/c_api.cc:300] Operation '{name:'dense_311/kernel/Assign' id:47028 op device:{requested: '', assigned: ''} def:{{{node dense_311/kernel/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_311/kernel, dense_311/kernel/Initializer/random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# /home/nikhil/.local/lib/python3.10/site-packages/keras/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2023-04-28 00:46:07.493109: W tensorflow/c/c_api.cc:300] Operation '{name:'dense_311/Softmax' id:47039 op device:{requested: '', assigned: ''} def:{{{node dense_311/Softmax}} = Softmax[T=DT_FLOAT, _has_manual_control_dependencies=true](dense_311/BiasAdd)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.

# %%
cm = confusion_matrix(Y_test,y_preds)
ax = plt.subplot()
sns.heatmap(cm,annot=True,ax=ax)

labels = target['mood']
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix')
ax.xaxis.set_ticklabels(labels)
ax.yaxis.set_ticklabels(labels)
plt.show()

print("Accuracy Score",accuracy_score(Y_test,y_preds))
# Out:
# Accuracy Score 0.6956521739130435

# %%
def predict_mood(id_song):
    #Join the model and the scaler in a Pipeline
    pip = Pipeline([('minmaxscaler',MinMaxScaler()),('keras',KerasClassifier(build_fn=base_model,epochs=300,
                                                                             batch_size=200,verbose=0))])
    #Fit the Pipeline
    pip.fit(X2,encoded_y)

    #Obtain the features of the song
    preds = get_songs_features(id_song)
    #Pre-process the features to input the Model
    preds_features = np.array(preds[0][6:-2]).reshape(-1,1).T

    #Predict the features of the song
    results = pip.predict(preds_features)

    mood = np.array(target['mood'][target['encode']==int(results)])
    name_song = preds[0][0]
    artist = preds[0][2]
    
    return mood[0]
    # return print("{0} by {1} is a {2} song".format(name_song,artist,mood[0].upper()))
    #print(f"{name_song} by {artist} is a {mood[0].upper()} song")

# %%
data = pd.read_csv('data/data.csv')
for index, row in data.iterrows():
    song_id = row["id"]
    print("This is the song ID: ",song_id)
    mood = predict_mood(song_id)
    data.loc[index, 'mood'] = mood

data.to_csv('data/data.csv', index=False)
# Out:
# This is the song ID:  2J3ajGI1sVj9wnqThJHwPS
# /tmp/ipykernel_19696/4022687830.py:3: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   pip = Pipeline([('minmaxscaler',MinMaxScaler()),('keras',KerasClassifier(build_fn=base_model,epochs=300,
# 2023-04-28 00:56:08.036548: W tensorflow/c/c_api.cc:300] Operation '{name:'training_366/Adam/learning_rate/Assign' id:55676 op device:{requested: '', assigned: ''} def:{{{node training_366/Adam/learning_rate/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training_366/Adam/learning_rate, training_366/Adam/learning_rate/Initializer/initial_value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# /home/nikhil/.local/lib/python3.10/site-packages/keras/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2023-04-28 00:56:16.990769: W tensorflow/c/c_api.cc:300] Operation '{name:'dense_367/Softmax' id:55521 op device:{requested: '', assigned: ''} def:{{{node dense_367/Softmax}} = Softmax[T=DT_FLOAT, _has_manual_control_dependencies=true](dense_367/BiasAdd)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# This is the song ID:  4tRt91OQSbE9eFA3RwgqSd
# /tmp/ipykernel_19696/4022687830.py:3: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   pip = Pipeline([('minmaxscaler',MinMaxScaler()),('keras',KerasClassifier(build_fn=base_model,epochs=300,
# 2023-04-28 00:56:20.652916: W tensorflow/c/c_api.cc:300] Operation '{name:'training_368/Adam/decay/Assign' id:55974 op device:{requested: '', assigned: ''} def:{{{node training_368/Adam/decay/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training_368/Adam/decay, training_368/Adam/decay/Initializer/initial_value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# /home/nikhil/.local/lib/python3.10/site-packages/keras/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2023-04-28 00:56:29.879853: W tensorflow/c/c_api.cc:300] Operation '{name:'dense_369/Softmax' id:55824 op device:{requested: '', assigned: ''} def:{{{node dense_369/Softmax}} = Softmax[T=DT_FLOAT, _has_manual_control_dependencies=true](dense_369/BiasAdd)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[59], line 8
#       6     else:
#       7         print("This is the song ID: ",song_id)
# ----> 8         mood = predict_mood(song_id)
#       9         data.loc[index, 'mood'] = mood
#      11 data.to_csv('data/data.csv', index=False)
#
# Cell In[55], line 14, in predict_mood(id_song)
#      11 preds_features = np.array(preds[0][6:-2]).reshape(-1,1).T
#      13 #Predict the features of the song
# ---> 14 results = pip.predict(preds_features)
#      16 mood = np.array(target['mood'][target['encode']==int(results)])
#      17 name_song = preds[0][0]
#
# File ~/.local/lib/python3.10/site-packages/sklearn/pipeline.py:481, in Pipeline.predict(self, X, **predict_params)
#     479 for _, name, transform in self._iter(with_final=False):
#     480     Xt = transform.transform(Xt)
# --> 481 return self.steps[-1][1].predict(Xt, **predict_params)
#
# File ~/.local/lib/python3.10/site-packages/keras/wrappers/scikit_learn.py:265, in KerasClassifier.predict(self, x, **kwargs)
#     250 def predict(self, x, **kwargs):
#     251     """Returns the class predictions for the given test data.
#     252
#     253     Args:
#    (...)
#     263             Class predictions.
#     264     """
# --> 265     proba = self.model.predict(x, **kwargs)
#     266     if proba.shape[-1] > 1:
#     267         classes = proba.argmax(axis=-1)
#
# File ~/.local/lib/python3.10/site-packages/keras/engine/training_v1.py:1059, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1056 self._check_call_args("predict")
#    1058 func = self._select_training_loop(x)
# -> 1059 return func.predict(
#    1060     self,
#    1061     x=x,
#    1062     batch_size=batch_size,
#    1063     verbose=verbose,
#    1064     steps=steps,
#    1065     callbacks=callbacks,
#    1066     max_queue_size=max_queue_size,
#    1067     workers=workers,
#    1068     use_multiprocessing=use_multiprocessing,
#    1069 )
#
# File ~/.local/lib/python3.10/site-packages/keras/engine/training_arrays_v1.py:801, in ArrayLikeTrainingLoop.predict(self, model, x, batch_size, verbose, steps, callbacks, **kwargs)
#     797 batch_size = model._validate_or_infer_batch_size(batch_size, steps, x)
#     798 x, _, _ = model._standardize_user_data(
#     799     x, check_steps=True, steps_name="steps", steps=steps
#     800 )
# --> 801 return predict_loop(
#     802     model,
#     803     x,
#     804     batch_size=batch_size,
#     805     verbose=verbose,
#     806     steps=steps,
#     807     callbacks=callbacks,
#     808 )
#
# File ~/.local/lib/python3.10/site-packages/keras/engine/training_arrays_v1.py:421, in model_iteration(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq, mode, validation_in_fit, prepared_feed_values_from_dataset, steps_name, **kwargs)
#     416 callbacks._call_batch_hook(
#     417     mode, "begin", batch_index, batch_logs
#     418 )
#     420 # Get outputs.
# --> 421 batch_outs = f(ins_batch)
#     422 if not isinstance(batch_outs, list):
#     423     batch_outs = [batch_outs]
#
# File ~/.local/lib/python3.10/site-packages/keras/backend.py:4606, in GraphExecutionFunction.__call__(self, inputs)
#    4597 # Refresh callable if anything has changed.
#    4598 if (
#    4599     self._callable_fn is None
#    4600     or feed_arrays != self._feed_arrays
#    (...)
#    4604     or session != self._session
#    4605 ):
# -> 4606     self._make_callable(feed_arrays, feed_symbols, symbol_vals, session)
#    4608 fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    4609 self._call_fetch_callbacks(fetched[-len(self._fetches) :])
#
# File ~/.local/lib/python3.10/site-packages/keras/backend.py:4531, in GraphExecutionFunction._make_callable(self, feed_arrays, feed_symbols, symbol_vals, session)
#    4529     callable_opts.run_options.CopyFrom(self.run_options)
#    4530 # Create callable.
# -> 4531 callable_fn = session._make_callable_from_options(callable_opts)
#    4532 # Cache parameters corresponding to the generated callable, so that
#    4533 # we can detect future mismatches and refresh the callable.
#    4534 self._callable_fn = callable_fn
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/client/session.py:1513, in BaseSession._make_callable_from_options(self, callable_options)
#    1503 def _make_callable_from_options(self, callable_options):
#    1504   """Returns a handle to a "callable" with the given options.
#    1505
#    1506   Args:
#    (...)
#    1511     A handle to the new callable.
#    1512   """
# -> 1513   self._extend_graph()
#    1514   return BaseSession._Callable(self, callable_options)
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/client/session.py:1401, in BaseSession._extend_graph(self)
#    1399 def _extend_graph(self):
#    1400   with self._graph._session_run_lock():  # pylint: disable=protected-access
# -> 1401     tf_session.ExtendSession(self._session)
#
# KeyboardInterrupt:
